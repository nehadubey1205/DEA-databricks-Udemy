-- %% [markdown]
-- #### Transform customer data
-- replace null
-- remove duplicates
-- CAST the columns, write trnasformed data

-- %%
SELECT * FROM gizmobox.bronze.v_customers where customer_id is NOT NULL Order by customer_id;

-- %%
SELECT DISTINCT * From gizmobox.bronze.v_customers where customer_id is NOT NULL Order by customer_id;

-- %%
CREATE or REPLACE TEMPORARY view v_customers_distinct as
SELECT DISTINCT * FROM gizmobox.bronze.v_customers where customer_id is NOT NULL Order by customer_id;

-- %%
SELECT customer_id, max(created_timestamp) as max_cretaed_timestamp from v_customers_distinct group by customer_id order by customer_id;
SELECT * FROM v_customers_distinct where customer_id;

-- %%
With cte_max as (
SELECT customer_id, max(created_timestamp) as max_cretaed_timestamp from v_customers_distinct group by customer_id order by customer_id);
