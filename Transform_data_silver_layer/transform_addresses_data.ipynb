-- %% [markdown]
-- Pivot

-- %%
SELECT customer_id,
       address_type,
       address_line_1,
       city,
       state,
       postcode
FROM gizmobox.bronze.v_addresses;

-- %%
SELECT * from gizmobox.bronze.v
