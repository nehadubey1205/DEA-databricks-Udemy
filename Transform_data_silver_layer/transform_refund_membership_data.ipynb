-- %% [markdown]
-- 1: extract specific portion of the string from refund_reason using split function
-- 2: extract specific portion of the string from refund_reason using regexp_extract function
-- 3) extract date time using refund_timestamp

-- %%
SELECT refund_id,
payment_id,
refund_timestamp,
refund_reason
from hive_metastore.bronze.refunds;

-- %% [markdown]
-- extract customer_id from file path, write transformed data to silver layer

-- %%
SELECT * FROM gizmobox.bronze.v_memberships;

-- %% [markdown]
-- regex_extract

-- %%
SELECT regexp_extract(path, '.*/([0-9]+)\\.png$', 1) AS customer_id
FROM gizmobox.bronze.v_memberships;

-- %%
CREATE TABLE gizmobox.silver.v_memberships as
SELECT regexp_extract(path, '.*/([0-9]+)\\.png$', 1) AS customer_id
FROM gizmobox.bronze.v_memberships;

-- %%
SELECT * FROM gizmobox.silver.v_memberships;
