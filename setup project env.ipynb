-- %% [markdown]
-- setup project env and practice mendalin

-- %%
%fs ls 'abfs://gizmobox@deanewxteraldeltalake.dfs.core.windows.net/'

-- %%
CREATE EXTERNAL LOCATION IF NOT EXISTS dea_course_external_gizmobox
URL 'abfss://gizmobox@deanewxteraldeltalake.dfs.core.windows.net/'
WITH (STORAGE CREDENTIAL `dea-course-ext-sc`)
COMMENT 'external location for Gizmobox Lakehouse';

-- %%
%fs ls 'abfs://gizmobox@deanewxteraldeltalake.dfs.core.windows.net/'

-- %%
SHOW CATALOGS;

-- %%
CREATE CATALOG IF NOT EXISTS gizmobox
  MANAGED LOCATION 'abfs://gizmobox@deanewxteraldeltalake.dfs.core.windows.net/'
  COMMENT 'Gizmobox Lakehouse' ;

-- %%
SHOW CATALOGS;

-- %%
SELECT current_catalog();

-- %%
USE CATALOG gizmobox;

-- %%
SELECT current_catalog();

-- %% [markdown]
-- Create Schema
-- 0) landing
-- 1) bronze
-- 2) silver
-- 3) gold

-- %%
CREATE SCHEMA IF NOT EXISTS landing
MANAGED LOCATION 'abfss://gizmobox@deanewxteraldeltalake.dfs.core.windows.net/landing/';

-- %%
%fs ls 'abfss://gizmobox@deanewxteraldeltalake.dfs.core.windows.net/landing/operation_data/'

-- %%
SHOW SCHEMAS;

-- %%
CREATE SCHEMA IF NOT EXISTS silver
MANAGED LOCATION 'abfss://gizmobox@deanewxteraldeltalake.dfs.core.windows.net/silver/';
CREATE SCHEMA IF NOT EXISTS bronze
MANAGED LOCATION 'abfss://gizmobox@deanewxteraldeltalake.dfs.core.windows.net/bronze/';
CREATE SCHEMA IF NOT EXISTS gold
MANAGED LOCATION 'abfss://gizmobox@deanewxteraldeltalake.dfs.core.windows.net/gold/';
CREATE SCHEMA IF NOT EXISTS landing
MANAGED LOCATION 'abfss://gizmobox@deanewxteraldeltalake.dfs.core.windows.net/landing/';

-- %%
SHOW SCHEMAS;

-- %% [markdown]
-- Create volume

-- %%
USE CATALOG gizmobox;
USE SCHEMA landing;
CREATE EXTERNAL VOLUME IF NOT EXISTS operation_data
LOCATION 'abfss://gizmobox@deanewxteraldeltalake.dfs.core.windows.net/landing/operation_data/';

-- %%
%fs ls /Volumes/gizmobox/landing/operation_data/

-- %%
%fs ls /Volumes/gizmobox/landing/operation_data/addresses/
