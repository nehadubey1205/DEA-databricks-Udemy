-- %%
%fs ls 'abfs://democontainer@deanewxteraldeltalake.dfs.core.windows.net/'

-- %%
%sql
CREATE EXTERNAL LOCATION IF NOT EXISTS dea_course_external_demo
URL 'abfss://democontainer@deanewxteraldeltalake.dfs.core.windows.net/'
WITH (STORAGE CREDENTIAL `dea-course-ext-sc`)
COMMENT 'external location for storage';
