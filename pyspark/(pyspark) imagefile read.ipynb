# %%
# %fs ls /Volumes/gizmobox/landing/operation_data/memberships/

# %%
df = spark.read.format("binaryFile").load("/Volumes/gizmobox/landing/operation_data/memberships/2024-10/*.png")
display(df)

# %%
df = spark.read.format("binaryFile").load("/Volumes/gizmobox/landing/operation_data/memberships/*/*.png")
display(df)

# %% [markdown]
# create table in bronze schema

# %%
df.writeTo('gizmobox.bronze.py_memberships').createOrReplace()

# %%
# %sql
SELECT * FROM gizmobox.bronze.v_memberships;
