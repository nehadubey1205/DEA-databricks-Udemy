-- %%
%fs ls /Volumes/gizmobox/landing/operation_data/memberships/

-- %%
SELECT * FROM binaryFile.`/Volumes/gizmobox/landing/operation_data/memberships/*/*.png`

-- %%
CREATE OR REPLACE VIEW gizmobox.bronze.v_memberships
As 
SELECT * FROM binaryFile.`/Volumes/gizmobox/landing/operation_data/memberships/*/*.png`

-- %%
SELECT * FROM gizmobox.bronze.v_memberships;
