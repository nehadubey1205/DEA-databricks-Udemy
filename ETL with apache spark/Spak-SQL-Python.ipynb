-- %% [markdown]
-- Run SQL command using pyhton

-- %%
SELECT * FROM json.`/Volumes/gizmobox/landing/operation_data/customers`

-- %%
spark.sql('SELECT * FROM json.`/Volumes/gizmobox/landing/operation_data/customers`')

-- %%
spark.read.format.('json').load(`/Volumes/gizmobox/landing/operation_data/customers`)

-- %%
spark.read.format("json").load(`/Volumes/gizmobox/landing/operation_data/customers`)
