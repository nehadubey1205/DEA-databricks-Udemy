-- %%
SELECT * FROM csv.`/Volumes/gizmobox/landing/operation_data/addresses`

-- %%
SELECT * FROM read_files('/Volumes/gizmobox/landing/operation_data/addresses',
                        format=> 'csv',
                        delimiter=>'\t',
                        header => true);

-- %%
CREATE OR REPLACE VIEW gizmobox.bronze.v_customers as 
SELECT * FROM read_files('/Volumes/gizmobox/landing/operation_data/addresses',
                        format=> 'csv',
                        delimiter=>'\t',
                        header => true);

-- %%
SELECT * FROM gizmobox.bronze.v_customers;

-- %% [markdown]
-- Create External Table

-- %%
%fs ls 'abfss://gizmobox@deanewxteraldeltalake.dfs.core.windows.net/landing/external_data/payments'

-- %%
CREATE TABLE IF NOT EXISTS gizmobox.bronze.payments
(payment_id INT, order_id INT, payment_timestamp TIMESTAMP, payment_status INT, payment_method STRING)
USING csv
OPTIONS (header = "true",
         delimiter = ","
)
LOCaTION 'abfss://gizmobox@deanewxteraldeltalake.dfs.core.windows.net/landing/external_data/payments'

-- %%
SELECT * FROM gizmobox.bronze.payments;

-- %% [markdown]
-- If you want to see table table type whther its external or something else run describe command

-- %%
DESCRIBE EXTENDED gizmobox.bronze.payments;

-- %% [markdown]
-- Adding/updating/deleting

-- %%
SELECT * FROM gizmobox.bronze.payments;

-- %%
DROP TABLE IF EXISTS gizmobox.bronze.payments

-- %%
SELECT * FROM gizmobox.bronze.payments;

-- %%
CREATE TABLE IF NOT EXISTS gizmobox.bronze.payments
(payment_id INT, order_id INT, payment_timestamp TIMESTAMP, payment_status INT, payment_method STRING)
USING csv
OPTIONS (header = "true",
         delimiter = ","
)
LOCaTION 'abfss://gizmobox@deanewxteraldeltalake.dfs.core.windows.net/landing/external_data/payments'

-- %%
SELECT * FROM gizmobox.bronze.payments;
