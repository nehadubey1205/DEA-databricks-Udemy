-- %% [markdown]
-- ### # Folder:
-- ######## /Volumes/gizmobox/landing/operation_data/customers/ : for all files inside customers folder
--
-- ### # Single json:
-- ######## /Volumes/gizmobox/landing/operation_data/customers/customers_2024_10.json : for single json which is customers_2024_10.json
--
-- ### # mutiple json:
-- ######### /Volumes/gizmobox/landing/operation_data/customers/customers_2024_*.json : for all _2024 customers

-- %%
%fs ls /Volumes/gizmobox/landing/operation_data/customers/

-- %%
SELECT * FROM json.`/Volumes/gizmobox/landing/operation_data/customers/customers_2024_10.json`

-- %%
SELECT * FROM json.`/Volumes/gizmobox/landing/operation_data/customers/customers_2024_*.json`

-- %%
SELECT * FROM json.`/Volumes/gizmobox/landing/operation_data/customers/`

-- %% [markdown]
-- Select file metadata

-- %%
SELECT _metadata.file_path AS file_path,
* 
FROM json.`/Volumes/gizmobox/landing/operation_data/customers`

-- %% [markdown]
-- 1) Query file using orders format

-- %%
SELECT * FROM json.`/Volumes/gizmobox/landing/operation_data/orders`;

-- %%
SELECT * FROM text.`/Volumes/gizmobox/landing/operation_data/orders`;

-- %% [markdown]
-- Create order view in bronze schema
-- Note: we give catelogname then schema name then view name eg below: catalog is gizmobox, schema is bronze and view name is v_order

-- %%
CREATE OR REPLACE VIEW gizmobox.bronze.v_orders
AS
SELECT * FROM text.`/Volumes/gizmobox/landing/operation_data/orders`;

-- %%
SELECT * FROM gizmobox.bronze.v_orders;
